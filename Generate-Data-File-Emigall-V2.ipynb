# %%
# ---------------------------------
# Import requirement modules
# ---------------------------------
import xlwings as xw
import pandas as pd
import numpy as np
import time
import datetime as dt
import requests
import json
import urllib3
from pathlib import Path

# %%
# -----------------------------------------
# Some Initial variable for the application
# -----------------------------------------
# numberOfFiles2Generate = 5
numberOfRecordsInEachFile = 10
fileNameStartWith = 'AMG-'

# %%
def createINITrecord(INIT_BPKIND, INIT_BU_GROUP, INIT_BU_RLTYP, INIT_BU_TYPE, INIT_MUSTER_KUN, INIT_PARTNER):
    v_INIT_record_formatted = f'{INIT_BPKIND}\t{INIT_BU_GROUP}\t{INIT_BU_RLTYP}\t{INIT_BU_TYPE}\t{INIT_MUSTER_KUN}\t{INIT_PARTNER}'
    return v_INIT_record_formatted

# %%
def createBUT000record(INIT_BPKIND, INIT_BU_GROUP, INIT_BU_RLTYP, INIT_BU_TYPE, INIT_MUSTER_KUN, INIT_PARTNER):
    v_INIT_record_formatted = f'{INIT_BPKIND}\t{INIT_BU_GROUP}\t{INIT_BU_RLTYP}\t{INIT_BU_TYPE}\t{INIT_MUSTER_KUN}\t{INIT_PARTNER}'
    return v_INIT_record_formatted

# %%
def createBUT020record(INIT_BPKIND, INIT_BU_GROUP, INIT_BU_RLTYP, INIT_BU_TYPE, INIT_MUSTER_KUN, INIT_PARTNER):
    v_INIT_record_formatted = f'{INIT_BPKIND}\t{INIT_BU_GROUP}\t{INIT_BU_RLTYP}\t{INIT_BU_TYPE}\t{INIT_MUSTER_KUN}\t{INIT_PARTNER}'
    return v_INIT_record_formatted

# %%
def createBUT0IDrecord(INIT_BPKIND, INIT_BU_GROUP, INIT_BU_RLTYP, INIT_BU_TYPE, INIT_MUSTER_KUN, INIT_PARTNER):
    v_INIT_record_formatted = f'{INIT_BPKIND}\t{INIT_BU_GROUP}\t{INIT_BU_RLTYP}\t{INIT_BU_TYPE}\t{INIT_MUSTER_KUN}\t{INIT_PARTNER}'
    return v_INIT_record_formatted

# %%
def createENDLINErecord(INIT_BPKIND, INIT_BU_GROUP, INIT_BU_RLTYP, INIT_BU_TYPE, INIT_MUSTER_KUN, INIT_PARTNER):
    v_INIT_record_formatted = f'{INIT_BPKIND}\t{INIT_BU_GROUP}\t{INIT_BU_RLTYP}\t{INIT_BU_TYPE}\t{INIT_MUSTER_KUN}\t{INIT_PARTNER}'
    return v_INIT_record_formatted

# %%
# ---------------------------------
# Initialize workbook by reading the existing one
# ---------------------------------
wb = xw.Book(r'DATA-Emigall\Emigall-BP-Source-Data.xlsx') 
app = xw.App(visible=False)  # Separate and hidden Excel instance

# %%
# ---------------------------------
# Reading Tab: DATATAB_1
# ---------------------------------
table_1_sheet = wb.sheets['DATATAB_1']
# Reading from Excel as Dataframe
df1 = table_1_sheet['A1'].expand().options(pd.DataFrame, chunksize=1000).value
df1
# Out:
#        INIT_BPKIND INIT_BU_GROUP INIT_BU_RLTYP  INIT_BU_TYPE INIT_MUSTER_KUN  \
# EXT_ID
# PY001         MCST          OLSM          None           2.0            None
# PY002         MCST          OLSM          None           2.0            None
# PY003         MCST          OLSM          None           2.0            None
# PY004         MCST          OLSM          None           2.0            None
# PY005         MCST          OLSM          None           2.0            None
# PY006         MCST          OLSM          None           2.0            None
# PY007         MCST          OLSM          None           2.0            None
# PY008         MCST          OLSM          None           2.0            None
# PY009         MCST          OLSM          None           2.0            None
# PY010         MCST          OLSM          None           2.0            None
# PY011         MCST          OLSM          None           2.0            None
# PY012         MCST          OLSM          None           2.0            None
# PY013         MCST          OLSM          None           2.0            None
# PY014         MCST          OLSM          None           2.0            None
# PY015         MCST          OLSM          None           2.0            None
# PY016         MCST          OLSM          None           2.0            None
# PY017         MCST          OLSM          None           2.0            None
# PY018         MCST          OLSM          None           2.0            None
# PY019         MCST          OLSM          None           2.0            None
# PY020         MCST          OLSM          None           2.0            None
# PY021         MCST          OLSM          None           2.0            None
# PY022         MCST          OLSM          None           2.0            None
# PY023         MCST          OLSM          None           2.0            None
# PY024         MCST          OLSM          None           2.0            None
# PY025         MCST          OLSM          None           2.0            None
# PY026         MCST          OLSM          None           2.0            None
# PY027         MCST          OLSM          None           2.0            None
# PY028         MCST          OLSM          None           2.0            None
# PY029         MCST          OLSM          None           2.0            None
# PY030         MCST          OLSM          None           2.0            None
# PY031         MCST          OLSM          None           2.0            None
# PY032         MCST          OLSM          None           2.0            None
# PY033         MCST          OLSM          None           2.0            None
# PY034         MCST          OLSM          None           2.0            None
# PY035         MCST          OLSM          None           2.0            None
# PY036         MCST          OLSM          None           2.0            None
# PY037         MCST          OLSM          None           2.0            None
#
#        INIT_PARTNER BUT000_AUGRP BUT000_BU_SORT1 BUT000_BU_SORT2  \
# EXT_ID
# PY001          None         None             DB1            DBB1
# PY002          None         None             DB2            DBB2
# PY003          None         None             DB3            DBB3
# PY004          None         None             DB4            DBB4
# PY005          None         None             DB5            DBB5
# PY006          None         None             DB6            DBB6
# PY007          None         None             DB7            DBB7
# PY008          None         None             DB8            DBB8
# PY009          None         None             DB9            DBB9
# PY010          None         None            DB10           DBB10
# PY011          None         None            DB11           DBB11
# PY012          None         None            DB12           DBB12
# PY013          None         None            DB13           DBB13
# PY014          None         None            DB14           DBB14
# PY015          None         None            DB15           DBB15
# PY016          None         None            DB16           DBB16
# PY017          None         None            DB17           DBB17
# PY018          None         None            DB18           DBB18
# PY019          None         None            DB19           DBB19
# PY020          None         None            DB20           DBB20
# PY021          None         None            DB21           DBB21
# PY022          None         None            DB22           DBB22
# PY023          None         None            DB23           DBB23
# PY024          None         None            DB24           DBB24
# PY025          None         None            DB25           DBB25
# PY026          None         None            DB26           DBB26
# PY027          None         None            DB27           DBB27
# PY028          None         None            DB28           DBB28
# PY029          None         None            DB29           DBB29
# PY030          None         None            DB30           DBB30
# PY031          None         None            DB31           DBB31
# PY032          None         None            DB32           DBB32
# PY033          None         None            DB33           DBB33
# PY034          None         None            DB34           DBB34
# PY035          None         None            DB35           DBB35
# PY036          None         None            DB36           DBB36
# PY037          None         None            DB37           DBB37
#
#        BUT000_LEGAL_ENTY  ... BUT000_NAME_GRP2 BUT000_NAME_LAST  \
# EXT_ID                    ...
# PY001               None  ...             None          BISWAS1
# PY002               None  ...             None          BISWAS2
# PY003               None  ...             None          BISWAS3
# PY004               None  ...             None          BISWAS4
# PY005               None  ...             None          BISWAS5
# PY006               None  ...             None          BISWAS6
# PY007               None  ...             None          BISWAS7
# PY008               None  ...             None          BISWAS8
# PY009               None  ...             None          BISWAS9
# PY010               None  ...             None         BISWAS10
# PY011               None  ...             None         BISWAS11
# PY012               None  ...             None         BISWAS12
# PY013               None  ...             None         BISWAS13
# PY014               None  ...             None         BISWAS14
# PY015               None  ...             None         BISWAS15
# PY016               None  ...             None         BISWAS16
# PY017               None  ...             None         BISWAS17
# PY018               None  ...             None         BISWAS18
# PY019               None  ...             None         BISWAS19
# PY020               None  ...             None         BISWAS20
# PY021               None  ...             None         BISWAS21
# PY022               None  ...             None         BISWAS22
# PY023               None  ...             None         BISWAS23
# PY024               None  ...             None         BISWAS24
# PY025               None  ...             None         BISWAS25
# PY026               None  ...             None         BISWAS26
# PY027               None  ...             None         BISWAS27
# PY028               None  ...             None         BISWAS28
# PY029               None  ...             None         BISWAS29
# PY030               None  ...             None         BISWAS30
# PY031               None  ...             None         BISWAS31
# PY032               None  ...             None         BISWAS32
# PY033               None  ...             None         BISWAS33
# PY034               None  ...             None         BISWAS34
# PY035               None  ...             None         BISWAS35
# PY036               None  ...             None         BISWAS36
# PY037               None  ...             None         BISWAS37
#
#        BUT000_NAME_ORG1 BUT000_NAME_ORG2 BUT000_NAME_ORG3 BUT000_NAME_ORG4  \
# EXT_ID
# PY001              DBX1             DBY1             None             None
# PY002              DBX2             DBY2             None             None
# PY003              DBX3             DBY3             None             None
# PY004              DBX4             DBY4             None             None
# PY005              DBX5             DBY5             None             None
# PY006              DBX6             DBY6             None             None
# PY007              DBX7             DBY7             None             None
# PY008              DBX8             DBY8             None             None
# PY009              DBX9             DBY9             None             None
# PY010             DBX10            DBY10             None             None
# PY011             DBX11            DBY11             None             None
# PY012             DBX12            DBY12             None             None
# PY013             DBX13            DBY13             None             None
# PY014             DBX14            DBY14             None             None
# PY015             DBX15            DBY15             None             None
# PY016             DBX16            DBY16             None             None
# PY017             DBX17            DBY17             None             None
# PY018             DBX18            DBY18             None             None
# PY019             DBX19            DBY19             None             None
# PY020             DBX20            DBY20             None             None
# PY021             DBX21            DBY21             None             None
# PY022             DBX22            DBY22             None             None
# PY023             DBX23            DBY23             None             None
# PY024             DBX24            DBY24             None             None
# PY025             DBX25            DBY25             None             None
# PY026             DBX26            DBY26             None             None
# PY027             DBX27            DBY27             None             None
# PY028             DBX28            DBY28             None             None
# PY029             DBX29            DBY29             None             None
# PY030             DBX30            DBY30             None             None
# PY031             DBX31            DBY31             None             None
# PY032             DBX32            DBY32             None             None
# PY033             DBX33            DBY33             None             None
# PY034             DBX34            DBY34             None             None
# PY035             DBX35            DBY35             None             None
# PY036             DBX36            DBY36             None             None
# PY037             DBX37            DBY37             None             None
#
#        BUT000_PARTGRPTYP BUT000_SOURCE BUT000_TITLE BUT000_TITLE_ACA1
# EXT_ID
# PY001               None          None         None              None
# PY002               None          None         None              None
# PY003               None          None         None              None
# PY004               None          None         None              None
# PY005               None          None         None              None
# PY006               None          None         None              None
# PY007               None          None         None              None
# PY008               None          None         None              None
# PY009               None          None         None              None
# PY010               None          None         None              None
# PY011               None          None         None              None
# PY012               None          None         None              None
# PY013               None          None         None              None
# PY014               None          None         None              None
# PY015               None          None         None              None
# PY016               None          None         None              None
# PY017               None          None         None              None
# PY018               None          None         None              None
# PY019               None          None         None              None
# PY020               None          None         None              None
# PY021               None          None         None              None
# PY022               None          None         None              None
# PY023               None          None         None              None
# PY024               None          None         None              None
# PY025               None          None         None              None
# PY026               None          None         None              None
# PY027               None          None         None              None
# PY028               None          None         None              None
# PY029               None          None         None              None
# PY030               None          None         None              None
# PY031               None          None         None              None
# PY032               None          None         None              None
# PY033               None          None         None              None
# PY034               None          None         None              None
# PY035               None          None         None              None
# PY036               None          None         None              None
# PY037               None          None         None              None
#
# [37 rows x 22 columns]

# %%
# --------------------------------------------------
# Reading Tab: DATATAB_1 and getting total row count
# --------------------------------------------------
data_info_sheet = wb.sheets['DATATAB_1']
lastcell = data_info_sheet.range(1,1).end('down').row #this just does ctrl+shift+down
print('Total Number of rows: {}'.format(lastcell)) #just so you know how many rows you have.
# Out:
# Total Number of rows: 38

# %%
wb.close()

# %%
# --------------------------------------------------------------------------
# Determine number of to be generated based on Number of record in each file 
# and actual number of records in excel sheet
# --------------------------------------------------------------------------
def determineNumberOfFiles(i_numberOfRecordsInEachFile, i_lastcell):
    o_numberOfFiles2Generate = (i_lastcell % i_numberOfRecordsInEachFile)
    l_quotient  = i_lastcell // i_numberOfRecordsInEachFile
    l_mod = i_lastcell % i_numberOfRecordsInEachFile
    if(l_mod > 0):
        o_numberOfFiles2Generate = l_quotient + 1
    else: 
        o_numberOfFiles2Generate = l_quotient
    return o_numberOfFiles2Generate

# %%
numberOfFiles2Generate = determineNumberOfFiles(numberOfRecordsInEachFile, lastcell)
print('Total Number of files to be generated: {}'.format(numberOfFiles2Generate))
# Out:
# Total Number of files to be generated: 4

# %%
def extractDataChunkForFile(fromCount, toCount):
    wb = None
    app = None
    data_sheet = None
    df1 = None
    
    wb = xw.Book(r'DATA-Emigall\Emigall-BP-Source-Data.xlsx') 
    # Start invisible Excel
    app = xw.App(visible=False, add_book=False)
    data_sheet = wb.sheets['DATATAB_1']
    # Reading from Excel as Dataframe
    df1 = data_sheet.range((fromCount,1),(toCount,11)).value
    wb.close()
    return df1

# %%
xdf1 = extractDataChunkForFile(1,5)
print(len(xdf1))
# looping
for x in range(0, len(xdf1), 1):
    lineToPrint = f'{xdf1[x][0]}\t{xdf1[x][1]}\t{xdf1[x][2]}\t{xdf1[x][3]}\t{xdf1[x][4]}\t{xdf1[x][5]}'
    # print(xdf1[x][0])
    print(lineToPrint)
# Out:
# 5
# EXT_ID	INIT_BPKIND	INIT_BU_GROUP	INIT_BU_RLTYP	INIT_BU_TYPE	INIT_MUSTER_KUN
# PY001	MCST	OLSM	None	2.0	None
# PY002	MCST	OLSM	None	2.0	None
# PY003	MCST	OLSM	None	2.0	None
# PY004	MCST	OLSM	None	2.0	None

# %%
# ***********************************************************************
# The parameter and it's description
# fileName - Tells what should be the file name for the program to create
# fromCount - It's the record number where it should start from in the input 
#             file (in this case it will be the Excel row)
# toCount - record number where it should stop of that iteration
# ***********************************************************************
def createDataFileIfNotExists(fileName, iterationCount):
    
    # Calculate fromCount & toCount based on the iteration number
    
    fromCount = None
    toCount = None
    
    if (iterationCount == 1):
        fromCount = 1
        toCount = numberOfRecordsInEachFile
    elif (iterationCount == numberOfFiles2Generate):
        fromCount = (numberOfRecordsInEachFile * (iterationCount - 1)) + 1
        toCount = lastcell
    else:
        fromCount = (numberOfRecordsInEachFile * (iterationCount - 1) + 1)
        toCount = (fromCount + numberOfRecordsInEachFile) -1
            
    print('The current count block is: {} & {} and I am in iteration {} & number of file to generate is: {}'.format(fromCount,toCount,iterationCount,numberOfFiles2Generate)) 
    
    
    f_content_new_line = "\n"
    with open(fileName,'w') as f:
        
        xdf1 = extractDataChunkForFile(1,numberOfRecordsInEachFile)
        print(len(xdf1))
        # looping
        for x in range(0, len(xdf1), 1):
            lineToPrint = f'{xdf1[x][0]}\t{xdf1[x][1]}\t{xdf1[x][2]}\t{xdf1[x][3]}\t{xdf1[x][4]}\t{xdf1[x][5]}'
            f_content = lineToPrint
            f.write(f_content)
            f.write(f_content_new_line)
        
        f_content = "Dipankar Biswas Test 2"
        f.write(f_content)
        f.write(f_content_new_line)
        f_content_INIT = createINITrecord('INIT', '1', '1', '1', '1', '1')
        f.write(str(f_content_INIT))
        f.write(f_content_new_line)
        f_content_BUT000 = createBUT000record('BUT000', '2', '2', '2', '2', '2')
        f.write(str(f_content_BUT000))
        f.write(f_content_new_line)
        f_content_BUT020 = createBUT020record('BUT020', '3', '3', '3', '3', '3')
        f.write(str(f_content_BUT020))
        f.write(f_content_new_line)
        f_content_BUT0ID = createBUT0IDrecord('BUT0ID', '4', '4', '4', '4', '4')
        f.write(str(f_content_BUT0ID))
        f.write(f_content_new_line)
        f_content_ENDE = createENDLINErecord('&ENDE', '5', '5', '5', '5', '5')
        f.write(str(f_content_ENDE))
        f.write(f_content_new_line)
        return f.mode

# %%
# ---------------------------------
# Program logic:
# 1. Create the function which is responsible for creating the data file with a file name being passed.
# 2. Create a function which is responsible for creating the Header data into the data file.
# 3. Create a function which will create the Line items for BUT000
# 4. Create a function which will create the Line items for BUT0ID
# 5. Create a function which will create the Line items for Ending line item.
# ---------------------------------
# Call this file creation in a loop based on variable: numberOfFiles2Generate
# Dynamically determine number of file to be generated by first reading all the record count from the file and then 
# divide it by number defined in variable numberOfRecordsInEachFile.

# myResponse = createDataFileIfNotExists('DATA-Emigall\emigall-1.txt')
# Looping ...
# range(start, stop, step)
#

for x in range(0, numberOfFiles2Generate, 1):
    myResponse = createDataFileIfNotExists('DATA-Emigall\{}emigall-{}.txt'.format(fileNameStartWith, x+1), x+1)
    print(myResponse)
# Out:
# The current count block is: 1 & 10 and I am in iteration 1 & number of file to generate is: 4
# 10
# w
# The current count block is: 11 & 20 and I am in iteration 2 & number of file to generate is: 4
# 10
# w
# The current count block is: 21 & 30 and I am in iteration 3 & number of file to generate is: 4
# 10
# w
# The current count block is: 31 & 38 and I am in iteration 4 & number of file to generate is: 4
# 10
# w

# %%
# ---------------------------------
# Initialize workbook by reading the existing one
# ---------------------------------
wb = xw.Book(r'DATA-Emigall\Emigall-BP-Source-Data.xlsx') 
app = xw.App(visible=False)  # Separate and hidden Excel instancetable_1_sheet = wb.sheets['DATATAB_1']
# ---------------------------------
# Reading Tab: DATATAB_1
# ---------------------------------
data_sheet = wb.sheets['DATATAB_1']
# Reading from Excel as Dataframe
df1 = data_sheet['A1'].expand().options(pd.DataFrame, chunksize=1000).value
# df1
wb.close()
